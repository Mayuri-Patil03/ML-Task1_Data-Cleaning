# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ds=pd.read_csv("employee_dataset_for_eda.csv")
ds
# Out:
#      Employee_ID  Age  Gender   Department       Location  \
# 0           1001   50  Female    Marketing         Austin
# 1           1002   36  Female        Sales       New York
# 2           1003   29    Male    Marketing  San Francisco
# 3           1004   42  Female           HR  San Francisco
# 4           1005   40  Female    Marketing         Austin
# ..           ...  ...     ...          ...            ...
# 195         1196   40  Female           HR       New York
# 196         1197   41    Male      Finance  San Francisco
# 197         1198   53    Male           HR       New York
# 198         1199   28  Female           HR         Austin
# 199         1200   54    Male  Engineering         Austin
#
#      Years_of_Experience  Monthly_Salary  Performance_Score
# 0                      4          105046               79.6
# 1                      1           59287               71.7
# 2                      5           69711               87.2
# 3                      1           41954               74.4
# 4                     12          103340               82.5
# ..                   ...             ...                ...
# 195                   12           93230               67.3
# 196                    9          104055               58.3
# 197                   17           86373               62.6
# 198                    7           61480               60.7
# 199                    7          115230               75.9
#
# [200 rows x 8 columns]

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Employee_ID          200 non-null    int64
#  1   Age                  200 non-null    int64
#  2   Gender               200 non-null    object
#  3   Department           200 non-null    object
#  4   Location             200 non-null    object
#  5   Years_of_Experience  200 non-null    int64
#  6   Monthly_Salary       200 non-null    int64
#  7   Performance_Score    200 non-null    float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 12.6+ KB

# %%
#Employee Count per Department

sns.countplot(data=ds,x="Department",palette='Set2')
plt.title("Employee Count per Department")
# Out:
# C:\Users\mayup\AppData\Local\Temp\ipykernel_14292\489244928.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=ds,x="Department",palette='Set2')
# Text(0.5, 1.0, 'Employee Count per Department')

# %% [markdown]
# finance department has more employees followed by Marketing department ans engineering department

# %%
#Gender Distribution
sns.countplot(data=ds,x='Gender',palette='coolwarm')
plt.title('Gender Distribution')
# Out:
# C:\Users\mayup\AppData\Local\Temp\ipykernel_14292\2175648347.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=ds,x='Gender',palette='coolwarm')
# Text(0.5, 1.0, 'Gender Distribution')

# %% [markdown]
# Female count is greater as compare to Male

# %%
#Employee Location Distribution

sns.countplot(data=ds,x='Location',palette='Spectral')
plt.title('Number of Employeesby location')
plt.xticks(rotation=45)
# Out:
# C:\Users\mayup\AppData\Local\Temp\ipykernel_14292\2825420850.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=ds,x='Location',palette='Spectral')
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Austin'),
#   Text(1, 0, 'New York'),
#   Text(2, 0, 'San Francisco'),
#   Text(3, 0, 'Seattle'),
#   Text(4, 0, 'Chicago')])

# %%
#Age Distribution

sns.histplot(ds['Age'],bins=10,kde=True)
plt.title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %% [markdown]
# peak between 45 to 50 have more experienced peoples than peak between 25 to 30

# %%
#Years of Experience Distribution
sns.histplot(ds['Years_of_Experience'],bins=15,kde=True)
plt.title('years of Experience')
# Out:
# Text(0.5, 1.0, 'years of Experience')

# %% [markdown]
# 5 years experience of every employee is greater than others

# %%
#Montly Salary Distribution

sns.boxplot(data=ds,y='Monthly_Salary',color='lightblue')
plt.title('Salary spread')
# Out:
# Text(0.5, 1.0, 'Salary spread')

# %% [markdown]
# salary lies between 60000 to 100000

# %%
#Average Salary of Department
sns.barplot(data=ds,x='Department',y='Monthly_Salary',estimator=np.mean,palette='viridis')
plt.title('Average Salary by Department')
# Out:
# C:\Users\mayup\AppData\Local\Temp\ipykernel_14292\2810606429.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=ds,x='Department',y='Monthly_Salary',estimator=np.mean,palette='viridis')
# Text(0.5, 1.0, 'Average Salary by Department')

# %% [markdown]
# finance department has more scope/Salary than others

# %%
#Performance Score by Department

sns.boxplot(data=ds,x='Department',y='Performance_Score',palette='pastel')
plt.title('Performance score by Department')
# Out:
# C:\Users\mayup\AppData\Local\Temp\ipykernel_14292\7958025.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=ds,x='Department',y='Performance_Score',palette='pastel')
# Text(0.5, 1.0, 'Performance score by Department')

# %%
#Salary Distribution by Gender

sns.violinplot(data=ds,x='Gender',y='Monthly_Salary',palette='muted')
plt.title("Salary by Gender")
# Out:
# C:\Users\mayup\AppData\Local\Temp\ipykernel_14292\4040310395.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=ds,x='Gender',y='Monthly_Salary',palette='muted')
# Text(0.5, 1.0, 'Salary by Gender')

# %%
sns.heatmap(ds[['Age','Years_of_Experience',"Monthly_Salary","Performance_Score"]].corr(),annot=True,cmap='coolwarm')
plt.title("Correlation Matrix")
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
#Salary vs experience scatter plot
sns.scatterplot(data=ds,x='Years_of_Experience',y='Monthly_Salary',hue='Department')
sns.title("Salary vs experience scatter plot")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 3
#       1 #Salary vs experience scatter plot
#       2 sns.scatterplot(data=ds,x='Years_of_Experience',y='Monthly_Salary',hue='Department')
# ----> 3 sns.title("Salary vs experience scatter plot")
#
# AttributeError: module 'seaborn' has no attribute 'title'

# %% [markdown]
# #fianace department has more salary than marketing and engineering
